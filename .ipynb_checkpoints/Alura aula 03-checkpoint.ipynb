# %% [markdown]
# ## AULA 3: DISTRIBUIÇÕES E CORRELAÇÕES ENTRE NOTAS

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

fonte = "https://github.com/alura-cursos/imersao-dados-2-2020/blob/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv?raw=true"

# %%
dados = pd.read_csv(fonte)
provas = ["NU_NOTA_CN","NU_NOTA_CH","NU_NOTA_MT","NU_NOTA_LC","NU_NOTA_REDACAO"]
dados["NU_NOTA_TOTAL"] = dados[provas].sum(axis=1)
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0  190001004661    2019                  1506138                Redenção
# 1  190001004674    2019                  1504208                  Marabá
# 2  190001004722    2019                  1501402                   Belém
# 3  190001004735    2019                  1507300      São Félix do Xingu
# 4  190001004776    2019                  1500800              Ananindeua
#
#    CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0                15               PA        17       M                1
# 1                15               PA        23       M                1
# 2                15               PA        35       F                2
# 3                15               PA        23       F                1
# 4                15               PA        16       F                1
#
#    TP_COR_RACA  ...  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025  \
# 0            3  ...     A     A    A     B    A     C     A     B     B
# 1            3  ...     A     A    B     A    A     B     A     A     B
# 2            1  ...     A     A    B     A    B     B     A     A     B
# 3            3  ...     A     A    B     A    A     B     A     A     B
# 4            3  ...     A     A    B     A    A     D     A     A     B
#
#    NU_NOTA_TOTAL
# 0         2288.9
# 1         1184.6
# 2         2350.5
# 3         2555.7
# 4         2803.5
#
# [5 rows x 137 columns]

# %%
provas.append("NU_NOTA_TOTAL")
dados[provas].query("NU_NOTA_TOTAL == 0").head()
# Out:
#     NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_MT  NU_NOTA_LC  NU_NOTA_REDACAO  \
# 10         NaN         NaN         NaN         NaN              NaN
# 11         NaN         NaN         NaN         NaN              NaN
# 26         NaN         NaN         NaN         NaN              NaN
# 38         NaN         NaN         NaN         NaN              NaN
# 40         NaN         NaN         NaN         NaN              NaN
#
#     NU_NOTA_TOTAL
# 10            0.0
# 11            0.0
# 26            0.0
# 38            0.0
# 40            0.0

# %%
dados_sem_notas_zero = dados.query("NU_NOTA_TOTAL != 0")
dados_sem_notas_zero.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0  190001004661    2019                  1506138                Redenção
# 1  190001004674    2019                  1504208                  Marabá
# 2  190001004722    2019                  1501402                   Belém
# 3  190001004735    2019                  1507300      São Félix do Xingu
# 4  190001004776    2019                  1500800              Ananindeua
#
#    CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0                15               PA        17       M                1
# 1                15               PA        23       M                1
# 2                15               PA        35       F                2
# 3                15               PA        23       F                1
# 4                15               PA        16       F                1
#
#    TP_COR_RACA  ...  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025  \
# 0            3  ...     A     A    A     B    A     C     A     B     B
# 1            3  ...     A     A    B     A    A     B     A     A     B
# 2            1  ...     A     A    B     A    B     B     A     A     B
# 3            3  ...     A     A    B     A    A     B     A     A     B
# 4            3  ...     A     A    B     A    A     D     A     A     B
#
#    NU_NOTA_TOTAL
# 0         2288.9
# 1         1184.6
# 2         2350.5
# 3         2555.7
# 4         2803.5
#
# [5 rows x 137 columns]

# %%
dados_sem_notas_zero.isnull().sum()
# Out:
# NU_INSCRICAO                   0
# NU_ANO                         0
# CO_MUNICIPIO_RESIDENCIA        0
# NO_MUNICIPIO_RESIDENCIA        0
# CO_UF_RESIDENCIA               0
# SG_UF_RESIDENCIA               0
# NU_IDADE                       0
# TP_SEXO                        0
# TP_ESTADO_CIVIL                0
# TP_COR_RACA                    0
# TP_NACIONALIDADE               0
# CO_MUNICIPIO_NASCIMENTO     2863
# NO_MUNICIPIO_NASCIMENTO     2863
# CO_UF_NASCIMENTO            2863
# SG_UF_NASCIMENTO            2863
# TP_ST_CONCLUSAO                0
# TP_ANO_CONCLUIU                0
# TP_ESCOLA                      0
# TP_ENSINO                  42436
# IN_TREINEIRO                   0
# CO_ESCOLA                  73250
# CO_MUNICIPIO_ESC           73250
# NO_MUNICIPIO_ESC           73250
# CO_UF_ESC                  73250
# SG_UF_ESC                  73250
# TP_DEPENDENCIA_ADM_ESC     73250
# TP_LOCALIZACAO_ESC         73250
# TP_SIT_FUNC_ESC            73250
# IN_BAIXA_VISAO                 0
# IN_CEGUEIRA                    0
#                            ...
# NU_NOTA_COMP3                216
# NU_NOTA_COMP4                216
# NU_NOTA_COMP5                216
# NU_NOTA_REDACAO              216
# Q001                           0
# Q002                           0
# Q003                           0
# Q004                           0
# Q005                           0
# Q006                           0
# Q007                           0
# Q008                           0
# Q009                           0
# Q010                           0
# Q011                           0
# Q012                           0
# Q013                           0
# Q014                           0
# Q015                           0
# Q016                           0
# Q017                           0
# Q018                           0
# Q019                           0
# Q020                           0
# Q021                           0
# Q022                           0
# Q023                           0
# Q024                           0
# Q025                           0
# NU_NOTA_TOTAL                  0
# Length: 137, dtype: int64

# %%
dados_sem_notas_zero.fillna(0,inplace=True)

# %%
dados_sem_notas_zero.isnull().sum()
# Out:
# NU_INSCRICAO               0
# NU_ANO                     0
# CO_MUNICIPIO_RESIDENCIA    0
# NO_MUNICIPIO_RESIDENCIA    0
# CO_UF_RESIDENCIA           0
# SG_UF_RESIDENCIA           0
# NU_IDADE                   0
# TP_SEXO                    0
# TP_ESTADO_CIVIL            0
# TP_COR_RACA                0
# TP_NACIONALIDADE           0
# CO_MUNICIPIO_NASCIMENTO    0
# NO_MUNICIPIO_NASCIMENTO    0
# CO_UF_NASCIMENTO           0
# SG_UF_NASCIMENTO           0
# TP_ST_CONCLUSAO            0
# TP_ANO_CONCLUIU            0
# TP_ESCOLA                  0
# TP_ENSINO                  0
# IN_TREINEIRO               0
# CO_ESCOLA                  0
# CO_MUNICIPIO_ESC           0
# NO_MUNICIPIO_ESC           0
# CO_UF_ESC                  0
# SG_UF_ESC                  0
# TP_DEPENDENCIA_ADM_ESC     0
# TP_LOCALIZACAO_ESC         0
# TP_SIT_FUNC_ESC            0
# IN_BAIXA_VISAO             0
# IN_CEGUEIRA                0
#                           ..
# NU_NOTA_COMP3              0
# NU_NOTA_COMP4              0
# NU_NOTA_COMP5              0
# NU_NOTA_REDACAO            0
# Q001                       0
# Q002                       0
# Q003                       0
# Q004                       0
# Q005                       0
# Q006                       0
# Q007                       0
# Q008                       0
# Q009                       0
# Q010                       0
# Q011                       0
# Q012                       0
# Q013                       0
# Q014                       0
# Q015                       0
# Q016                       0
# Q017                       0
# Q018                       0
# Q019                       0
# Q020                       0
# Q021                       0
# Q022                       0
# Q023                       0
# Q024                       0
# Q025                       0
# NU_NOTA_TOTAL              0
# Length: 137, dtype: int64

# %%
plt.figure(figsize=(8,8))
sns.distplot(dados_sem_notas_zero['NU_NOTA_TOTAL'])

# %%
plt.figure(figsize=(8,8))
sns.distplot(dados_sem_notas_zero["NU_NOTA_MT"])

# %%
plt.figure(figsize=(8,8))
sns.distplot(dados_sem_notas_zero["NU_NOTA_LC"])

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(data = dados_sem_notas_zero, x="NU_NOTA_MT", y="NU_NOTA_LC", hue="Q025")
plt.xlim((-50, 1050))
plt.ylim((-50, 1050))
# Out:
# (-50, 1050)

# %%
provas
# Out:
# ['NU_NOTA_CN',
#  'NU_NOTA_CH',
#  'NU_NOTA_MT',
#  'NU_NOTA_LC',
#  'NU_NOTA_REDACAO',
#  'NU_NOTA_TOTAL']

# %%
sns.pairplot(dados_sem_notas_zero[provas])

# %%
correlacao = dados_sem_notas_zero[provas].corr()
correlacao
# Out:
#                  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_MT  NU_NOTA_LC  \
# NU_NOTA_CN         1.000000    0.444041    0.861415    0.403168
# NU_NOTA_CH         0.444041    1.000000    0.464049    0.766937
# NU_NOTA_MT         0.861415    0.464049    1.000000    0.425065
# NU_NOTA_LC         0.403168    0.766937    0.425065    1.000000
# NU_NOTA_REDACAO    0.411476    0.541722    0.439199    0.545877
# NU_NOTA_TOTAL      0.819685    0.740110    0.844138    0.710509
#
#                  NU_NOTA_REDACAO  NU_NOTA_TOTAL
# NU_NOTA_CN              0.411476       0.819685
# NU_NOTA_CH              0.541722       0.740110
# NU_NOTA_MT              0.439199       0.844138
# NU_NOTA_LC              0.545877       0.710509
# NU_NOTA_REDACAO         1.000000       0.788114
# NU_NOTA_TOTAL           0.788114       1.000000

# %%
sns.heatmap(correlacao, cmap="Blues", center=0, annot=True)

# %% [markdown]
# Desafio1: Plotar as médias, medianas e moda nas notas de LC e MT (matiplotlib linha vertical)
#
# Desafio2: Melhorar a visualização da matriz de correlação e analisar mais detalhadamente.
#
# Desafio3: Filtrar as notas por seu estado ou sua cidade e refazer as análises, verificando se são semelhantes ao geral.
#
# Desafio4: Pensar sobre a correlação entre matemática e Linguagens.

# %% [markdown]
# ## Minha analize começa a parti daqui
